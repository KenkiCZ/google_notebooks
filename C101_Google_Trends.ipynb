# %% [markdown]
# <a href="https://colab.research.google.com/github/KenkiCZ/google_notebooks/blob/main/C101_Google_Trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# Google Trends gives us an estimate of search volume. Let's explore if search popularity relates to other kinds of data. Perhaps there are patterns in Google's search volume and the price of Bitcoin or a hot stock like Tesla. Perhaps search volume for the term "Unemployment Benefits" can tell us something about the actual unemployment rate?
#
# Data Sources: <br>
# <ul>
# <li> <a href="https://fred.stlouisfed.org/series/UNRATE/">Unemployment Rate from FRED</a></li>
# <li> <a href="https://trends.google.com/trends/explore">Google Trends</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/TSLA/history?p=TSLA">Yahoo Finance for Tesla Stock Price</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD">Yahoo Finance for Bitcoin Stock Price</a> </li>
# </ul>

# %% [markdown]
# # Import Statements

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import matplotlib.pyplot as plt
DATA_PATH = "/content/drive/MyDrive/Programming/C101_Google_Trends/Data/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read the Data
#
# Download and add the .csv files to the same folder as your notebook.

# %%
df_tesla = pd.read_csv(DATA_PATH+'TESLA Search Trend vs Price.csv')

df_btc_search = pd.read_csv(DATA_PATH+'Bitcoin Search Trend.csv')
df_btc_price = pd.read_csv(DATA_PATH+'Daily Bitcoin Price.csv')

df_unemployment = pd.read_csv(DATA_PATH+'UE Benefits Search vs UE Rate 2004-19.csv')

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Tesla

# %% [markdown]
# **Challenge**: <br>
# <ul>
# <li>What are the shapes of the dataframes? DONE</li>
# <li>How many rows and columns? DONE</li>
# <li>What are the column names? </li>
# <li>Complete the f-string to show the largest/smallest number in the search data column DONE</li>
# <li>Try the <code>.describe()</code> function to see some useful descriptive statistics</li>
# <li>What is the periodicity of the time series data (daily, weekly, monthly)? </li>
# <li>What does a value of 100 in the Google Trend search popularity actually mean?</li>
# </ul>

# %%
f"Shapes are Tesla: {df_tesla.shape} BTC Search: {df_btc_search.shape} BTC Price: {df_btc_price.shape} Unemployment: {df_unemployment.shape}"
# Out:
# 'Shapes are Tesla: (124, 3) BTC Search: (73, 2) BTC Price: (2204, 3) Unemployment: (181, 3)'

# %%
df_tesla["TSLA_WEB_SEARCH"].min()
# Out:
# 2

# %%
print(f'Largest value for Tesla in Web Search: 31')
print(f'Smallest value for Tesla in Web Search: 2')
# Out:
# Largest value for Tesla in Web Search: 31
# Smallest value for Tesla in Web Search: 2

# %% [markdown]
# ### Unemployment Data

# %%
df_unemployment.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              181.000000  181.000000
# mean                35.110497    6.217680
# std                 20.484925    1.891859
# min                 14.000000    3.700000
# 25%                 21.000000    4.700000
# 50%                 26.000000    5.400000
# 75%                 45.000000    7.800000
# max                100.000000   10.000000

# %%
df_unemployment["UE_BENEFITS_WEB_SEARCH"].max()
# Out:
# 100

# %%
print('Largest value for "Unemployemnt Benefits" '
      f'in Web Search: 100')
# Out:
# Largest value for "Unemployemnt Benefits" in Web Search: 100

# %% [markdown]
# ### Bitcoin

# %%
df_btc_search["BTC_NEWS_SEARCH"].max()
# Out:
# 100

# %%
print(f'largest BTC News Search: 100')
# Out:
# largest BTC News Search: 100

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check for Missing Values

# %% [markdown]
# **Challenge**: Are there any missing values in any of the dataframes? If so, which row/rows have missing values? How many missing values are there?

# %%
print(df_tesla.isna().values.any())
print(df_btc_search.isna().values.any())
print(df_btc_price.isna().values.any()) # Missing value
print(df_unemployment.isna().values.any())
# Out:
# False
# False
# True
# False

# %%
df_btc_price[df_btc_price.isnull().any(axis=1)]
# Out:
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
df_btc_price.dropna(inplace=True)

# %%
print(f'Missing values for Tesla?: None')
print(f'Missing values for U/E?: None')
print(f'Missing values for BTC Search?: None')
# Out:
# Missing values for Tesla?: None
# Missing values for U/E?: None
# Missing values for BTC Search?: None

# %%
print(f'Missing values for BTC price?: Yes, [2148, 2148]')
# Out:
# Missing values for BTC price?: Yes, [2148, 2148]

# %%
print(f'Number of missing values: 2')
# Out:
# Number of missing values: 2

# %% [markdown]
# **Challenge**: Remove any missing values that you found.

# %% [markdown]
# ### Convert Strings to DateTime Objects

# %% [markdown]
# **Challenge**: Check the data type of the entries in the DataFrame MONTH or DATE columns. Convert any strings in to Datetime objects. Do this for all 4 DataFrames. Double check if your type conversion was successful.

# %%
df_tesla["MONTH"] = pd.to_datetime(df_tesla["MONTH"])
df_tesla
# Out:
#          MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0   2010-06-01                3        4.766000
# 1   2010-07-01                3        3.988000
# 2   2010-08-01                2        3.896000
# 3   2010-09-01                2        4.082000
# 4   2010-10-01                2        4.368000
# ..         ...              ...             ...
# 119 2020-05-01               16      167.000000
# 120 2020-06-01               17      215.962006
# 121 2020-07-01               24      286.152008
# 122 2020-08-01               23      498.320007
# 123 2020-09-01               31      407.339996
#
# [124 rows x 3 columns]

# %%
df_btc_search["MONTH"] = pd.to_datetime(df_btc_search["MONTH"])
df_btc_price["DATE"] = pd.to_datetime(df_btc_price["DATE"])
df_unemployment["MONTH"] = pd.to_datetime(df_unemployment["MONTH"])

# %%
df_btc_price["DATE"]
# Out:
# 0      2014-09-17
# 1      2014-09-18
# 2      2014-09-19
# 3      2014-09-20
# 4      2014-09-21
#           ...
# 2199   2020-09-24
# 2200   2020-09-25
# 2201   2020-09-26
# 2202   2020-09-27
# 2203   2020-09-28
# Name: DATE, Length: 2203, dtype: datetime64[ns]

# %% [markdown]
# ### Converting from Daily to Monthly Data
#
# [Pandas .resample() documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) <br>

# %%
df_btc_price.resample(rule="M", on="DATE").last()
# Out:
#                    CLOSE        VOLUME
# DATE
# 2014-09-30    386.944000  3.470730e+07
# 2014-10-31    338.321014  1.254540e+07
# 2014-11-30    378.046997  9.194440e+06
# 2014-12-31    320.192993  1.394290e+07
# 2015-01-31    217.464005  2.334820e+07
# ...                  ...           ...
# 2020-05-31   9461.058594  2.777329e+10
# 2020-06-30   9137.993164  1.573580e+10
# 2020-07-31  11323.466797  2.316047e+10
# 2020-08-31  11680.820313  2.228593e+10
# 2020-09-30  10912.536133  2.122653e+10
#
# [73 rows x 2 columns]

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Notebook Formatting & Style Helpers

# %%
# Create locators for ticks on the time axis

# %%
  from pandas.plotting import register_matplotlib_converters
  register_matplotlib_converters()

# %% [markdown]
# ### Tesla Stock Price v.s. Search Volume

# %% [markdown]
# **Challenge:** Plot the Tesla stock price against the Tesla search volume using a line chart and two different axes. Label one axis 'TSLA Stock Price' and the other 'Search Trend'.

# %%
ax1 = plt.gca()
ax2 = ax1.twinx()


ax1.plot(df_tesla["MONTH"], df_tesla["TSLA_WEB_SEARCH"])
ax2.plot(df_tesla["MONTH"], df_tesla["TSLA_USD_CLOSE"])

# %% [markdown]
# **Challenge**: Add colours to style the chart. This will help differentiate the two lines and the axis labels. Try using one of the blue [colour names](https://matplotlib.org/3.1.1/gallery/color/named_colors.html) for the search volume and a HEX code for a red colour for the stock price.
# <br>
# <br>
# Hint: you can colour both the [axis labels](https://matplotlib.org/3.3.2/api/text_api.html#matplotlib.text.Text) and the [lines](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D) on the chart using keyword arguments (kwargs).

# %%
plt.figure(figsize=(10,6), dpi=150)
plt.xticks(rotation=45, ha='right')
plt.title("Tesla Web Search vs Price")

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_xlabel("Date")
ax1.set_ylabel("Web Search", color="#3365FF")
ax2.set_ylabel("USD Revenue", color="#CE0900")

ax1.set_ylim(0,df_tesla["TSLA_WEB_SEARCH"].max()+5)
ax2.set_ylim(0, df_tesla["TSLA_USD_CLOSE"].max()+5)
date_strings = pd.to_datetime(("5.5.2010", "1.1.2021"))
ax1.set_xlim(date_strings)
ax2.set_xlim(date_strings)

ax1.plot(df_tesla["MONTH"], df_tesla["TSLA_WEB_SEARCH"], color="#3365FF", linewidth=2)
ax2.plot(df_tesla["MONTH"], df_tesla["TSLA_USD_CLOSE"], color="#CE0900", linewidth=2)

plt.show()

# %% [markdown]
# **Challenge**: Make the chart larger and easier to read.
# 1. Increase the figure size (e.g., to 14 by 8).
# 2. Increase the font sizes for the labels and the ticks on the x-axis to 14.
# 3. Rotate the text on the x-axis by 45 degrees.
# 4. Make the lines on the chart thicker.
# 5. Add a title that reads 'Tesla Web Search vs Price'
# 6. Keep the chart looking sharp by changing the dots-per-inch or [DPI value](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.figure.html).
# 7. Set minimum and maximum values for the y and x axis. Hint: check out methods like [set_xlim()](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.set_xlim.html).
# 8. Finally use [plt.show()](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.show.html) to display the chart below the cell instead of relying on the automatic notebook output.

# %% [markdown]
# How to add tick formatting for dates on the x-axis.

# %%
import matplotlib.dates as mdates

# Locators and DateFormatter
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")


plt.figure(figsize=(10,6), dpi=150)
plt.xticks(rotation=45, ha='right')
plt.title("Tesla Web Search vs Price")

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_xlabel("Date")
ax1.set_ylabel("Web Search", color="#3365FF")
ax2.set_ylabel("USD Revenue", color="#CE0900")

ax1.set_ylim(0,df_tesla["TSLA_WEB_SEARCH"].max()+5)
ax2.set_ylim(0, df_tesla["TSLA_USD_CLOSE"].max()+5)
date_strings = pd.to_datetime(("5.5.2010", "1.1.2021"))
ax1.set_xlim(date_strings)
ax2.set_xlim(date_strings)

# Adding Tics
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)


ax1.plot(df_tesla["MONTH"], df_tesla["TSLA_WEB_SEARCH"], color="#3365FF", linewidth=2)
ax2.plot(df_tesla["MONTH"], df_tesla["TSLA_USD_CLOSE"], color="#CE0900", linewidth=2)

plt.show()

# %% [markdown]
# ### Bitcoin (BTC) Price v.s. Search Volume

# %% [markdown]
# **Challenge**: Create the same chart for the Bitcoin Prices vs. Search volumes. <br>
# 1. Modify the chart title to read 'Bitcoin News Search vs Resampled Price' <br>
# 2. Change the y-axis label to 'BTC Price' <br>
# 3. Change the y- and x-axis limits to improve the appearance <br>
# 4. Investigate the [linestyles](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html ) to make the BTC price a dashed line <br>
# 5. Investigate the [marker types](https://matplotlib.org/3.2.1/api/markers_api.html) to make the search datapoints little circles <br>
# 6. Were big increases in searches for Bitcoin accompanied by big increases in the price?

# %%
import matplotlib.dates as mdates

# Locators and DateFormatter
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")


plt.figure(figsize=(10,6), dpi=150)
plt.xticks(rotation=45, ha='right')
plt.title("Bitcoin News Search vs Resampled Price")

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_xlabel("Date")
ax1.set_ylabel("Web Search", color="#3365FF")
ax2.set_ylabel("BTC Price", color="#CE0900")

ax1.set_ylim(0, df_btc_search["BTC_NEWS_SEARCH"].max()+5)
ax2.set_ylim(0, df_btc_price["CLOSE"].max()+5)
date_strings = pd.to_datetime((df_btc_search["MONTH"].min(), df_btc_search["MONTH"].max()))
ax1.set_xlim(date_strings)
ax2.set_xlim(date_strings)

# Adding Tics
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)


ax1.plot(df_btc_search["MONTH"], df_btc_search["BTC_NEWS_SEARCH"], color="#3365FF", marker=".")
ax2.plot(df_btc_price["DATE"], df_btc_price["CLOSE"].rolling(window=10).mean(), color="#CE0900", linestyle="dashed")

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.interpolate import make_interp_spline
import numpy as np
import pandas as pd

# Assuming df_btc_search and df_btc_price are already defined DataFrames with appropriate data

# Locators and DateFormatter
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")

plt.figure(figsize=(10,6), dpi=150)
plt.xticks(rotation=45, ha='right')
plt.title("Bitcoin News Search vs Resampled Price")

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_xlabel("Date")
ax1.set_ylabel("Web Search", color="#3365FF")
ax2.set_ylabel("USD Revenue", color="#CE0900")

# Convert date to numerical format for spline interpolation
date_nums = mdates.date2num(df_btc_search["MONTH"])

# Create spline for BTC_NEWS_SEARCH
X_Y_Spline = make_interp_spline(date_nums, df_btc_search["BTC_NEWS_SEARCH"], k=3)
X_ = np.linspace(date_nums.min(), date_nums.max(), 500)
Y_ = X_Y_Spline(X_)

# Convert numerical dates back to datetime for plotting
X_dates = mdates.num2date(X_)

# Set limits
ax1.set_ylim(0, df_btc_search["BTC_NEWS_SEARCH"].max() + 5)
ax2.set_ylim(0, df_btc_price["CLOSE"].max() + 5)
date_strings = pd.to_datetime(["2010-05-05", "2021-01-01"])
ax1.set_xlim(date_strings)
ax2.set_xlim(date_strings)

# Adding Tics
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# Plot the smoothed BTC_NEWS_SEARCH data
ax1.plot(X_dates, Y_, color="#3365FF")

# Plot the BTC price data
ax2.plot(df_btc_price["DATE"], df_btc_price["CLOSE"], color="#CE0900")

plt.show()

# %% [markdown]
# ### Unemployement Benefits Search vs. Actual Unemployment in the U.S.

# %% [markdown]
# **Challenge** Plot the search for "unemployment benefits" against the unemployment rate.
# 1. Change the title to: Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate <br>
# 2. Change the y-axis label to: FRED U/E Rate <br>
# 3. Change the axis limits <br>
# 4. Add a grey [grid](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.grid.html) to the chart to better see the years and the U/E rate values. Use dashes for the line style<br>
# 5. Can you discern any seasonality in the searches? Is there a pattern?

# %%
import matplotlib.dates as mdates

# Locators and DateFormatter
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")

plt.figure(figsize=(10,6), dpi=150)
plt.xticks(rotation=45, ha='right')
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate')

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_xlabel("Date")
ax1.set_ylabel("Web Search", color="#3365FF")
ax2.set_ylabel("FRED U/E Rate", color="#CE0900")

ax1.set_ylim(0, df_unemployment["UE_BENEFITS_WEB_SEARCH"].max()+5)
ax2.set_ylim(0, df_unemployment["UNRATE"].max()+1)
date_strings = pd.to_datetime((df_unemployment["MONTH"].min(), df_unemployment["MONTH"].max()))
ax1.set_xlim(date_strings)
ax2.set_xlim(date_strings)

# Adding Tics
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.grid(linestyle='--', linewidth=0.5)
ax1.plot(df_unemployment["MONTH"], df_unemployment["UE_BENEFITS_WEB_SEARCH"], color="#3365FF")
ax2.plot(df_unemployment["MONTH"], df_unemployment["UNRATE"], color="#CE0900", linestyle="dashed")

plt.show()

# %% [markdown]
# **Challenge**: Calculate the 3-month or 6-month rolling average for the web searches. Plot the 6-month rolling average search data against the actual unemployment. What do you see in the chart? Which line moves first?

# %%
import matplotlib.dates as mdates

# Locators and DateFormatter
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")

plt.figure(figsize=(10,6), dpi=150)
plt.xticks(rotation=45, ha='right')
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate')

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_xlabel("Date")
ax1.set_ylabel("Web Search", color="#3365FF")
ax2.set_ylabel("FRED U/E Rate", color="#CE0900")

ax1.set_ylim(0, df_unemployment["UE_BENEFITS_WEB_SEARCH"].max()+5)
ax2.set_ylim(0, df_unemployment["UNRATE"].max()+2.5)
date_strings = pd.to_datetime((df_unemployment["MONTH"].min(), df_unemployment["MONTH"].max()))
ax1.set_xlim(date_strings)
ax2.set_xlim(date_strings)

# Adding Tics
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.grid(linestyle='--', linewidth=0.5)
ax1.plot(df_unemployment["MONTH"], df_unemployment["UE_BENEFITS_WEB_SEARCH"].rolling(window=6).mean(), color="#3365FF")
ax2.plot(df_unemployment["MONTH"], df_unemployment["UNRATE"].rolling(window=6).mean(), color="#CE0900")

plt.show()

# %% [markdown]
# ### Including 2020 in Unemployment Charts

# %% [markdown]
# **Challenge**: Read the data in the 'UE Benefits Search vs UE Rate 2004-20.csv' into a DataFrame. Convert the MONTH column to Pandas Datetime objects and then plot the chart. What do you see?

# %%
df_unemployment_2020 = pd.read_csv("/content/drive/MyDrive/Programming/C101_Google_Trends/Data/UE Benefits Search vs UE Rate 2004-20.csv")
df_unemployment_2020["MONTH"] = pd.to_datetime(df_unemployment_2020["MONTH"])

# %%
# Locators and DateFormatter
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter("%Y")

plt.figure(figsize=(10,6), dpi=150)
plt.xticks(rotation=45, ha='right')
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate')

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_xlabel("Date")
ax1.set_ylabel("Web Search", color="#3365FF")
ax2.set_ylabel("FRED U/E Rate", color="#CE0900")

ax1.set_ylim(0, df_unemployment_2020["UE_BENEFITS_WEB_SEARCH"].max())
ax2.set_ylim(0, df_unemployment_2020["UNRATE"].max())
date_strings = pd.to_datetime((df_unemployment_2020["MONTH"].min(), df_unemployment_2020["MONTH"].max()))
ax1.set_xlim(date_strings)
ax2.set_xlim(date_strings)

# Adding Tics
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.grid(linestyle='--', linewidth=0.5)
ax1.plot(df_unemployment_2020["MONTH"], df_unemployment_2020["UE_BENEFITS_WEB_SEARCH"].rolling(window=1).mean(), color="#3365FF")
ax2.plot(df_unemployment_2020["MONTH"], df_unemployment_2020["UNRATE"].rolling(window=1).mean(), color="#CE0900")

plt.show()
