# %% [markdown]
# <a href="https://colab.research.google.com/github/KenkiCZ/google_notebooks/blob/main/C102_Apps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_apps = pd.read_csv("/content/drive/MyDrive/Programming/C102_Apps/apps.csv")

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
print(f"There {df_apps.shape[0]} rows and {df_apps.shape[1]} columns")
print(f"The columns names are as follow: {[column_name for column_name in df_apps.columns]}")
print("\n")
df_apps.sample(5)
# Out:
# There 10841 rows and 12 columns
# The columns names are as follow: ['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type', 'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver']
#                                              App          Category  Rating  \
# 6712                             Dance On Mobile            FAMILY    4.10
# 10748                            Google Calendar      PRODUCTIVITY    4.20
# 7692                 IHG®: Hotel Deals & Rewards  TRAVEL_AND_LOCAL    4.30
# 885    Pyaar Ek Dhoka hai Game - Anti Valentines            FAMILY     NaN
# 7138               Free & Premium VPN - FinchVPN             TOOLS    4.20
#
#        Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 6712     23609     31.00    1,000,000  Free     0           Teen
# 10748   858208      4.00  500,000,000  Free     0       Everyone
# 7692     18622     44.00    1,000,000  Free     0       Everyone
# 885          8     17.00          100  Free     0       Everyone
# 7138     19096     10.00    1,000,000  Free     0       Everyone
#
#                Genres       Last_Updated         Android_Ver
# 6712           Casual     April 13, 2018          4.0 and up
# 10748    Productivity     August 6, 2018  Varies with device
# 7692   Travel & Local     August 3, 2018          4.4 and up
# 885            Casual  February 11, 2018          4.1 and up
# 7138            Tools       July 5, 2018          4.1 and up

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.drop(["Last_Updated", "Android_Ver"], axis=1)
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type   Price Content_Rating  \
# 0             0      8.70              0  Paid  $13.99           Teen
# 1             0     33.00              0  Paid   $2.99       Everyone
# 2             0      5.50              0  Paid   $1.49       Everyone
# 3             0     19.00              0   NaN       0   Everyone 10+
# 4             0     10.00              0  Free       0       Everyone
# ...         ...       ...            ...   ...     ...            ...
# 10836  27723193     76.00  1,000,000,000  Free       0   Everyone 10+
# 10837  27724094     76.00  1,000,000,000  Free       0   Everyone 10+
# 10838  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10839  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10840  27711703     76.00  1,000,000,000  Free       0   Everyone 10+
#
#                 Genres
# 0               Social
# 1            Education
# 2      Personalization
# 3             Strategy
# 4             Business
# ...                ...
# 10836           Arcade
# 10837           Arcade
# 10838           Arcade
# 10839           Arcade
# 10840           Arcade
#
# [10841 rows x 10 columns]

# %%
df_apps.isna().any(axis=1).value_counts()
# Out:
# False    9365
# True     1476
# Name: count, dtype: int64

# %%
df_apps.duplicated().value_counts()
# Out:
# False    10358
# True       483
# Name: count, dtype: int64

# %%
df_clean = df_apps.drop_duplicates(subset=["App", "Type", "Price"])

# %%
df_clean = df_clean.dropna()

# %%
df_clean
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10824                                     Google Drive        PRODUCTIVITY
# 10828                                          YouTube       VIDEO_PLAYERS
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10831                                      Google News  NEWS_AND_MAGAZINES
# 10835                                   Subway Surfers                GAME
#
#        Rating   Reviews  Size_MBs       Installs  Type  Price Content_Rating  \
# 21       5.00         4     25.00              1  Free      0       Everyone
# 28       5.00         2     20.00              1  Paid  $1.49       Everyone
# 47       5.00         2     16.00              1  Paid  $0.99       Everyone
# 82       5.00         7     19.00              5  Free      0       Everyone
# 99       5.00         1      4.60              5  Free      0       Everyone
# ...       ...       ...       ...            ...   ...    ...            ...
# 10824    4.40   2731171      4.00  1,000,000,000  Free      0       Everyone
# 10828    4.30  25655305      4.65  1,000,000,000  Free      0           Teen
# 10829    3.70    906384      4.65  1,000,000,000  Free      0           Teen
# 10831    3.90    877635     13.00  1,000,000,000  Free      0           Teen
# 10835    4.50  27722264     76.00  1,000,000,000  Free      0   Everyone 10+
#
#                         Genres      Last_Updated         Android_Ver
# 21                     Medical    August 2, 2018        4.0.3 and up
# 28                      Arcade  February 8, 2017          2.3 and up
# 47                      Arcade     March 3, 2017          2.3 and up
# 82                      Arcade     July 23, 2018          4.1 and up
# 99                     Medical    August 2, 2018          4.0 and up
# ...                        ...               ...                 ...
# 10824             Productivity    August 6, 2018  Varies with device
# 10828  Video Players & Editors    August 2, 2018  Varies with device
# 10829  Video Players & Editors    August 6, 2018  Varies with device
# 10831         News & Magazines    August 1, 2018          4.4 and up
# 10835                   Arcade     July 12, 2018          4.1 and up
#
# [8196 rows x 12 columns]

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
# df_clean = df_apps.drop_duplicates(subset=["App", "Type", "Price"])

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_clean.sort_values(by="Rating", ascending=False).head(5)
# Out:
#                                            App   Category  Rating  Reviews  \
# 21                         KBA-EZ Health Guide    MEDICAL    5.00        4
# 1790                          SUMMER SONIC app     EVENTS    5.00        4
# 1769  Yazdani Cd Center EllahAbad Official App     FAMILY    5.00        8
# 985                                DW Security   BUSINESS    5.00        6
# 981                               EU Exit poll  LIFESTYLE    5.00       10
#
#       Size_MBs Installs  Type Price Content_Rating         Genres  \
# 21       25.00        1  Free     0       Everyone        Medical
# 1790     61.00      500  Free     0       Everyone         Events
# 1769      3.80      500  Free     0       Everyone  Entertainment
# 985      15.00      100  Free     0       Everyone       Business
# 981       9.40      100  Free     0       Everyone      Lifestyle
#
#           Last_Updated   Android_Ver
# 21      August 2, 2018  4.0.3 and up
# 1790     July 24, 2018    4.4 and up
# 1769  January 12, 2018    4.0 and up
# 985      July 25, 2018    4.1 and up
# 981      July 15, 2016    4.1 and up

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_clean.sort_values(by="Size_MBs", ascending=False).head(5)
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres    Last_Updated Android_Ver
# 9942   Lifestyle;Pretend Play   July 16, 2018  4.0 and up
# 10687                  Arcade   July 25, 2018  4.1 and up
# 9943                   Action    July 9, 2018  4.0 and up
# 9944               Simulation    May 31, 2018  4.0 and up
# 3144         Health & Fitness  August 2, 2018  5.0 and up

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
[df_clean.sort_values(by="Reviews", ascending=False)[:50]["Price"]!="0"]=="True"
# Out:
# False

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_clean["Content_Rating"].value_counts()
values_, indexes_ = ratings.values, ratings.index

# %%
import plotly.express as px

# %%
fig = px.pie(labels=indexes_, values=values_, names=indexes_, title="Content Rating")
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52a43162-5e0e-41ef-9085-eb6790172741" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52a43162-5e0e-41ef-9085-eb6790172741")) {                    Plotly.newPlot(                        "52a43162-5e0e-41ef-9085-eb6790172741",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6618,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}} ...

# %%
print(px.pie().update_traces())
# Out:
# Figure({
#     'data': [{'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#               'hovertemplate': '<extra></extra>',
#               'legendgroup': '',
#               'name': '',
#               'showlegend': False,
#               'type': 'pie'}],
#     'layout': {'legend': {'tracegroupgap': 0}, 'margin': {'t': 60}, 'template': '...'}
# })

# %%
fig = px.pie(labels=indexes_, values=values_, names=indexes_, title="Content Rating", hole=0.7)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8de109c8-7c58-47b1-a2a2-6bb36cd1a7fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8de109c8-7c58-47b1-a2a2-6bb36cd1a7fb")) {                    Plotly.newPlot(                        "8de109c8-7c58-47b1-a2a2-6bb36cd1a7fb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.7,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6618,912,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_clean[df_clean["Installs"].str.replace(',', '').astype(int)>=1000000000]
# Out:
#                                             App             Category  Rating  \
# 10783                         Google Play Books  BOOKS_AND_REFERENCE    3.90
# 10784  Messenger – Text and Video Chat for Free        COMMUNICATION    4.00
# 10785                        WhatsApp Messenger        COMMUNICATION    4.40
# 10786              Google Chrome: Fast & Secure        COMMUNICATION    4.30
# 10787                                     Gmail        COMMUNICATION    4.30
# 10788                                  Hangouts        COMMUNICATION    4.00
# 10792             Skype - free IM & video calls        COMMUNICATION    4.10
# 10803                         Google Play Games        ENTERTAINMENT    4.30
# 10805                                  Facebook               SOCIAL    4.10
# 10806                                 Instagram               SOCIAL    4.50
# 10807                                   Google+               SOCIAL    4.20
# 10813                             Google Photos          PHOTOGRAPHY    4.50
# 10817                 Maps - Navigate & Explore     TRAVEL_AND_LOCAL    4.30
# 10818                        Google Street View     TRAVEL_AND_LOCAL    4.20
# 10822                                    Google                TOOLS    4.40
# 10824                              Google Drive         PRODUCTIVITY    4.40
# 10828                                   YouTube        VIDEO_PLAYERS    4.30
# 10829                   Google Play Movies & TV        VIDEO_PLAYERS    3.70
# 10831                               Google News   NEWS_AND_MAGAZINES    3.90
# 10835                            Subway Surfers                 GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10783   1433233      5.70  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10786   9642995      3.50  1,000,000,000  Free     0       Everyone
# 10787   4604324      3.50  1,000,000,000  Free     0       Everyone
# 10788   3419249      3.50  1,000,000,000  Free     0       Everyone
# 10792  10484169      3.50  1,000,000,000  Free     0       Everyone
# 10803   7165362      9.35  1,000,000,000  Free     0           Teen
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10807   4831125      5.30  1,000,000,000  Free     0           Teen
# 10813  10858556      6.90  1,000,000,000  Free     0       Everyone
# 10817   9235155     12.00  1,000,000,000  Free     0       Everyone
# 10818   2129689     12.00  1,000,000,000  Free     0       Everyone
# 10822   8033493      3.40  1,000,000,000  Free     0       Everyone
# 10824   2731171      4.00  1,000,000,000  Free     0       Everyone
# 10828  25655305      4.65  1,000,000,000  Free     0           Teen
# 10829    906384      4.65  1,000,000,000  Free     0           Teen
# 10831    877635     13.00  1,000,000,000  Free     0           Teen
# 10835  27722264     76.00  1,000,000,000  Free     0   Everyone 10+
#
#                         Genres    Last_Updated         Android_Ver
# 10783        Books & Reference  August 3, 2018  Varies with device
# 10784            Communication  August 1, 2018  Varies with device
# 10785            Communication  August 3, 2018  Varies with device
# 10786            Communication  August 1, 2018  Varies with device
# 10787            Communication  August 2, 2018  Varies with device
# 10788            Communication   July 21, 2018  Varies with device
# 10792            Communication  August 3, 2018  Varies with device
# 10803            Entertainment   July 16, 2018  Varies with device
# 10805                   Social  August 3, 2018  Varies with device
# 10806                   Social   July 31, 2018  Varies with device
# 10807                   Social   July 26, 2018  Varies with device
# 10813              Photography  August 6, 2018  Varies with device
# 10817           Travel & Local   July 31, 2018  Varies with device
# 10818           Travel & Local  August 6, 2018  Varies with device
# 10822                    Tools  August 3, 2018  Varies with device
# 10824             Productivity  August 6, 2018  Varies with device
# 10828  Video Players & Editors  August 2, 2018  Varies with device
# 10829  Video Players & Editors  August 6, 2018  Varies with device
# 10831         News & Magazines  August 1, 2018          4.4 and up
# 10835                   Arcade   July 12, 2018          4.1 and up

# %%
df_clean["Installs"] = df_clean["Installs"].str.replace(',', '').astype(int)
df_clean["Installs"]
# Out:
# 21                1
# 28                1
# 47                1
# 82                5
# 99                5
#             ...
# 10824    1000000000
# 10828    1000000000
# 10829    1000000000
# 10831    1000000000
# 10835    1000000000
# Name: Installs, Length: 8196, dtype: int64

# %%
df_clean[["App", "Installs"]].groupby("Installs").count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         697
# 5000         425
# 10000        987
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      606
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_clean["Price"] = df_clean["Price"].str.replace("$","").astype(float)

# %%
df_clean[["Price", "App"]].groupby("Price").count()
# Out:
#          App
# Price
# 0.00    7593
# 0.99     104
# 1.00       2
# 1.20       1
# 1.29       1
# ...      ...
# 299.99     1
# 379.99     1
# 389.99     1
# 399.99    11
# 400.00     1
#
# [73 rows x 1 columns]

# %%
df_clean.sort_values(by="Price", ascending=False)
# Out:
#                                App   Category  Rating   Reviews  Size_MBs  \
# 3946      I'm Rich - Trump Edition  LIFESTYLE    3.60       275      7.30
# 3114                     I am Rich    FINANCE    4.30       180      3.80
# 2461            I AM RICH PRO PLUS    FINANCE    4.00        36     41.00
# 3145            I am rich(premium)    FINANCE    3.50       472      0.94
# 5765                     I am rich  LIFESTYLE    3.80      3547      1.80
# ...                            ...        ...     ...       ...       ...
# 4508   myAir™ for Air10™ by ResMed    MEDICAL    3.70       236     18.00
# 4507                 AK Math Coach     FAMILY    3.60       283     18.00
# 4506          Forgotten Hill: Fall       GAME    4.40      1063     18.00
# 4505                AE Video Poker       GAME    4.00       721     18.00
# 10835               Subway Surfers       GAME    4.50  27722264     76.00
#
#          Installs  Type  Price Content_Rating     Genres       Last_Updated  \
# 3946        10000  Paid 400.00       Everyone  Lifestyle        May 3, 2018
# 3114         5000  Paid 399.99       Everyone    Finance     March 22, 2018
# 2461         1000  Paid 399.99       Everyone    Finance      June 25, 2018
# 3145         5000  Paid 399.99       Everyone    Finance        May 1, 2017
# 5765       100000  Paid 399.99       Everyone  Lifestyle   January 12, 2018
# ...           ...   ...    ...            ...        ...                ...
# 4508        50000  Free   0.00       Everyone    Medical      July 25, 2018
# 4507        50000  Free   0.00       Everyone  Education       May 19, 2015
# 4506        50000  Free   0.00           Teen  Adventure   October 30, 2017
# 4505        50000  Free   0.00           Teen     Casino  December 31, 2015
# 10835  1000000000  Free   0.00   Everyone 10+     Arcade      July 12, 2018
#
#         Android_Ver
# 3946     4.1 and up
# 3114     4.2 and up
# 2461     4.1 and up
# 3145     4.4 and up
# 5765   4.0.3 and up
# ...             ...
# 4508     5.0 and up
# 4507   2.3.3 and up
# 4506     3.0 and up
# 4505     2.3 and up
# 10835    4.1 and up
#
# [8196 rows x 12 columns]

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_under_250 = df_clean.drop(axis=1, index= df_clean[df_clean["Price"]>250].index)

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_under_250["Revenue_Estimate"] = df_under_250["Price"] * df_under_250["Installs"]
df_under_250["Revenue_Estimate"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 8181 entries, 21 to 10835
# Series name: Revenue_Estimate
# Non-Null Count  Dtype
# --------------  -----
# 8181 non-null   float64
# dtypes: float64(1)
# memory usage: 127.8 KB

# %%
df_under_250[["Revenue_Estimate", "App", "Category"]].sort_values(by="Revenue_Estimate",ascending=False).head(10)
# Out:
#       Revenue_Estimate                            App       Category
# 9220     69,900,000.00                      Minecraft         FAMILY
# 8825      9,900,000.00                  Hitman Sniper           GAME
# 7151      6,990,000.00  Grand Theft Auto: San Andreas           GAME
# 7977      5,990,000.00        Sleep as Android Unlock      LIFESTYLE
# 7477      5,990,000.00            Facetune - For Free    PHOTOGRAPHY
# 6594      4,990,000.00            DraStic DS Emulator           GAME
# 6082      2,995,000.00                   Weather Live        WEATHER
# 7954      2,990,000.00                    Bloons TD 5         FAMILY
# 6856      2,990,000.00                        Threema  COMMUNICATION
# 7044      2,990,000.00                         Tasker          TOOLS

# %%
df_under_250['Revenue_Estimate'] = df_under_250.Installs.mul(df_under_250.Price)
df_under_250.sort_values('Revenue_Estimate', ascending=False)[:15]
# Out:
#                                                    App         Category  \
# 9220                                         Minecraft           FAMILY
# 8825                                     Hitman Sniper             GAME
# 7151                     Grand Theft Auto: San Andreas             GAME
# 7977                           Sleep as Android Unlock        LIFESTYLE
# 7477                               Facetune - For Free      PHOTOGRAPHY
# 6594                               DraStic DS Emulator             GAME
# 6082                                      Weather Live          WEATHER
# 7954                                       Bloons TD 5           FAMILY
# 6856                                           Threema    COMMUNICATION
# 7044                                            Tasker            TOOLS
# 6746                        Card Wars - Adventure Time           FAMILY
# 7633                           Five Nights at Freddy's             GAME
# 4772  Human Anatomy Atlas 2018: Complete 3D Human Body          MEDICAL
# 6406                             NBA JAM by EA SPORTS™           FAMILY
# 6496                             Beautiful Widgets Pro  PERSONALIZATION
#
#       Rating  Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 9220    4.50  2376564     19.00  10000000  Paid   6.99   Everyone 10+
# 8825    4.60   408292     29.00  10000000  Paid   0.99     Mature 17+
# 7151    4.40   348962     26.00   1000000  Paid   6.99     Mature 17+
# 7977    4.50    23966      0.85   1000000  Paid   5.99       Everyone
# 7477    4.40    49553     48.00   1000000  Paid   5.99       Everyone
# 6594    4.60    87766     12.00   1000000  Paid   4.99       Everyone
# 6082    4.50    76593      4.75    500000  Paid   5.99       Everyone
# 7954    4.60   190086     94.00   1000000  Paid   2.99       Everyone
# 6856    4.50    51110      3.50   1000000  Paid   2.99       Everyone
# 7044    4.60    43045      3.40   1000000  Paid   2.99       Everyone
# 6746    4.30   129603     23.00   1000000  Paid   2.99   Everyone 10+
# 7633    4.60   100805     50.00   1000000  Paid   2.99           Teen
# 4772    4.50     2921     25.00    100000  Paid  24.99       Everyone
# 6406    4.30    56444     43.00    500000  Paid   4.99       Everyone
# 6496    4.20    97890     14.00   1000000  Paid   2.49       Everyone
#
#                          Genres       Last_Updated         Android_Ver  \
# 9220  Arcade;Action & Adventure      July 24, 2018  Varies with device
# 8825                     Action      July 12, 2018          4.1 and up
# 7151                     Action     March 21, 2015          3.0 and up
# 7977                  Lifestyle      June 27, 2018          4.0 and up
# 7477                Photography      July 25, 2018          4.1 and up
# 6594                     Action      July 19, 2016          2.3 and up
# 6082                    Weather  November 21, 2017  Varies with device
# 7954                   Strategy      July 13, 2018        2.3.3 and up
# 6856              Communication     August 3, 2018  Varies with device
# 7044                      Tools      June 25, 2018  Varies with device
# 6746    Card;Action & Adventure  February 11, 2016        2.3.3 and up
# 7633                     Action   December 2, 2014          2.3 and up
# 4772                    Medical       May 25, 2018          5.0 and up
# 6406  Sports;Action & Adventure   February 8, 2017          2.3 and up
# 6496            Personalization    August 24, 2016          2.3 and up
#
#       Revenue_Estimate
# 9220     69,900,000.00
# 8825      9,900,000.00
# 7151      6,990,000.00
# 7977      5,990,000.00
# 7477      5,990,000.00
# 6594      4,990,000.00
# 6082      2,995,000.00
# 7954      2,990,000.00
# 6856      2,990,000.00
# 7044      2,990,000.00
# 6746      2,990,000.00
# 7633      2,990,000.00
# 4772      2,499,000.00
# 6406      2,495,000.00
# 6496      2,490,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
top_categories = df_clean["Category"].value_counts()[:10]

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x = top_categories.index, y = top_categories.values)
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1da4a378-2bf7-48a8-b1b3-65e35f4199ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1da4a378-2bf7-48a8-b1b3-65e35f4199ba")) {                    Plotly.newPlot(                        "1da4a378-2bf7-48a8-b1b3-65e35f4199ba",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","FINANCE","LIFESTYLE","PRODUCTIVITY","PERSONALIZATION","MEDICAL","PHOTOGRAPHY","BUSINESS"],"xaxis":"x","y":[1610,910,719,302,302,301,296,291,263,262],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}," ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_group = df_clean[["Category", "Installs"]].groupby("Category")
category_table = category_group.sum() / category_group.count()
category_chart_data = category_table.sort_values(by="Installs", ascending = True)[:15]

# %%
bar = px.bar(y = category_chart_data.index, x = category_chart_data["Installs"], orientation="h")
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="10b2c085-0dbc-4ee8-aeaf-9098e01267ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10b2c085-0dbc-4ee8-aeaf-9098e01267ff")) {                    Plotly.newPlot(                        "10b2c085-0dbc-4ee8-aeaf-9098e01267ff",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[117397.51202749141,354431.3333333333,622322.2,640861.9047619047,727805.4794520548,813796.875,832057.4074074074,1051585.1492537314,1507656.9536423841,1565838.7096774194,1668020.2649006622,1872673.7704918033,2251890.9574468085,2641290.534351145,2756260.614906832],"xaxis":"x","y":["MEDICAL","EVENTS","PARENTING","BEAUTY","AUTO_AND_VEHICLES","LIBRARIES_AND_DEMO","COMICS","DATING","FINANCE","HOUSE_AND_HOME","LIFESTYLE","ART_AND_DESIGN","FOOD_AND_DRINK","BUSINESS","FAMILY"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outline ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
df_scatter = df_clean[["Category", "Installs", "App"]].groupby("Category").agg({"App":"count", "Installs":"sum"}).sort_values("Installs", ascending=False)
df_scatter
# Out:
#                       App     Installs
# Category
# GAME                  910  13858762717
# COMMUNICATION         257  11039241530
# TOOLS                 719   8099724500
# PRODUCTIVITY          301   5788070180
# SOCIAL                203   5487841475
# PHOTOGRAPHY           263   4649143130
# FAMILY               1610   4437579590
# VIDEO_PLAYERS         148   3916897200
# TRAVEL_AND_LOCAL      187   2894859300
# NEWS_AND_MAGAZINES    204   2369110650
# ENTERTAINMENT         102   2113660000
# BOOKS_AND_REFERENCE   169   1665791655
# PERSONALIZATION       296   1532341930
# SHOPPING              180   1400331540
# HEALTH_AND_FITNESS    243   1134006220
# SPORTS                260   1096431465
# BUSINESS              262    692018120
# LIFESTYLE             302    503742120
# MAPS_AND_NAVIGATION   118    503267560
# FINANCE               302    455312400
# WEATHER                72    361096500
# EDUCATION             118    352852000
# FOOD_AND_DRINK         94    211677750
# DATING                134    140912410
# ART_AND_DESIGN         61    114233100
# HOUSE_AND_HOME         62     97082000
# AUTO_AND_VEHICLES      73     53129800
# LIBRARIES_AND_DEMO     64     52083000
# COMICS                 54     44931100
# MEDICAL               291     34162676
# PARENTING              50     31116110
# BEAUTY                 42     26916200
# EVENTS                 45     15949410

# %%
scatter = px.scatter(df_scatter, x = "App",
                     y = "Installs",
                     color='Installs',
                     size="App",
                     labels={
                     "Installs": "Installs",
                     "App": "Number of Apps (Lower=More Concentrated)"},
                     title="Category Concetration",
                     hover_name = df_scatter.index)
scatter.update_layout(yaxis=dict(type="log"))
scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0f1c974d-1322-419f-8074-6aee8bbfc1cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f1c974d-1322-419f-8074-6aee8bbfc1cd")) {                    Plotly.newPlot(                        "0f1c974d-1322-419f-8074-6aee8bbfc1cd",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eNumber of Apps (Lower=More Concentrated)=%{marker.size}\u003cbr\u003eInstalls=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["GAME","COMMUNICATION","TOOLS","PRODUCTIVITY","SOCIAL","PHOTOGRAPHY","FAMILY","VIDEO_PLAYERS","TRAVEL_AND_LOCAL","NEWS_AND_MAGAZINES","ENTERTAINMENT","BOOKS_AND_REFERENCE","PERSONALIZATION","SHOPPING","HEALTH_AND_FITNESS","SPORTS","BUSINESS","LIFESTYLE","MAPS_AND_NAVIGATION","FINANCE","WEATHER","EDUCATION","FOOD_AND_DRINK","DATING","ART_AND_DESIGN","HOUSE_AND_HOME","AUTO_AND_VEHICLES","LIBRARIES_AND_DEMO","COMICS","MEDICAL","PARENTING","BEAUTY","EVENTS"],"legendgroup":"","marker":{"color":[13858762717,11039241530,8099724500,5788070180,5487841475,4649143130,4437579590,3916897200,2894859300,2369110650,2113660000,1665791655,1532341930,1400331540,1134006220,1096431465,692018120,503742120,503267560,455312400,361096500,352852000,211677750,140912410,114233100,97082000,53129800,52083000,44931100,34162676,31116110,26916200,15949410],"coloraxis":"coloraxis","size":[910,257,719,301,203,263,1610,148,187,204,102,169,296,180,243,260,262,302,118,302,72,118,94,134,61,62,73,64,54,291,50,42,45],"sizemode":"area","sizeref":4.025,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[910,257,719,301,203,263,1610,148,187,204,102,169,296,180,243,260,262,302,118,302,72,118,94,134,61,62,73,64,54,291,50,42,45],"xaxis":"x","y":[13858762717,11039241530,8099724500,5788070180,5487841475,4649143130,4437579590,3916897200,2894859300,2369110650,2113660000,1665791655,1532341930,1400331540,1134006220,1096431465,692018120,503742120,503267560,455312400,361096500,352852000,211677750,140912410,114233100,97082000,53129800,52083000,44931100,34162676,31116110,26916200,15949410],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3 ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
split_genres = df_clean["Genres"].str.replace(";"," ").str.split(expand=True).replace("&", None)
genre_popularity = split_genres.stack().value_counts(ascending=False)
genre_popularity = genre_popularity[:20]

# %%
bar_genre = px.bar(x = genre_popularity.index,
                  y = genre_popularity.values,
                  color = genre_popularity.values,
                  color_continuous_scale = "Agsunset",
                  hover_name = genre_popularity)

bar_genre.update_coloraxes(showscale=False)
bar_genre.update_xaxes(tickangle=45)
bar_genre.update_layout(title=dict(text="Top genres", font=dict(size=50),automargin=True, yref='paper'),
                        font=dict(family="Courier New, monospace", size=18),
                      xaxis_title='Genre',
                      yaxis_title='Number of Apps',
                      coloraxis_showscale=False)
bar_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fd3d3fe7-ace2-43f4-9a00-8fd77d89e514" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd3d3fe7-ace2-43f4-9a00-8fd77d89e514")) {                    Plotly.newPlot(                        "fd3d3fe7-ace2-43f4-9a00-8fd77d89e514",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[719.0,587.0,502.0,400.0,303.0,302.0,301.0,296.0,291.0,270.0,263.0,262.0,258.0,245.0,245.0,216.0,204.0,204.0,203.0,200.0],"legendgroup":"","marker":{"color":[719,587,502,400,303,302,301,296,291,270,263,262,258,245,245,216,204,204,203,200],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tools","Education","Entertainment","Action","Lifestyle","Finance","Productivity","Personalization","Medical","Sports","Photography","Business","Communication","Fitness","Health","Casual","Magazines","News","Social","Simulation"],"xaxis":"x","y":[719,587,502,400,303,302,301,296,291,270,263,262,258,245,245,216,204,204,203,200],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","col ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_type = df_clean.groupby(["Category", "Type"], as_index=False).agg({"App":pd.Series.count}).sort_values(by="App", ascending=False)
df_type
# Out:
#               Category  Type   App
# 19              FAMILY  Free  1456
# 25                GAME  Free   834
# 53               TOOLS  Free   656
# 21             FINANCE  Free   289
# 31           LIFESTYLE  Free   284
# ..                 ...   ...   ...
# 17       ENTERTAINMENT  Paid     2
# 24      FOOD_AND_DRINK  Paid     2
# 40           PARENTING  Paid     2
# 38  NEWS_AND_MAGAZINES  Paid     2
# 3    AUTO_AND_VEHICLES  Paid     1
#
# [61 rows x 3 columns]

# %%
bar_type = px.bar(df_type,
                  x = "Category",
                  y = "App",
                  color = "Type",
                  color_continuous_scale = "Agsunset",
                  hover_name = "Category",
                  barmode="group",
                  text_auto='.2s')


bar_type.update_xaxes(tickangle=90)
bar_type.update_layout(title=dict(text="Free vs Paid Apps by Category", font=dict(size=30)),
                      xaxis_title='Category',
                      yaxis_title='Number of Apps',
                      coloraxis_showscale=False,
                      yaxis=dict(type='log'))

bar_type.update_traces(textangle=0, textposition="outside", cliponaxis=False)
bar_type.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="171baa71-6cf1-4739-affd-f20f087bf57d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("171baa71-6cf1-4739-affd-f20f087bf57d")) {                    Plotly.newPlot(                        "171baa71-6cf1-4739-affd-f20f087bf57d",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eType=Free\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["FAMILY","GAME","TOOLS","FINANCE","LIFESTYLE","PRODUCTIVITY","BUSINESS","PHOTOGRAPHY","SPORTS","COMMUNICATION","HEALTH_AND_FITNESS","PERSONALIZATION","MEDICAL","NEWS_AND_MAGAZINES","SOCIAL","TRAVEL_AND_LOCAL","SHOPPING","BOOKS_AND_REFERENCE","VIDEO_PLAYERS","DATING","EDUCATION","MAPS_AND_NAVIGATION","ENTERTAINMENT","FOOD_AND_DRINK","AUTO_AND_VEHICLES","WEATHER","LIBRARIES_AND_DEMO","HOUSE_AND_HOME","ART_AND_DESIGN","COMICS","PARENTING","EVENTS","BEAUTY"],"legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2s}","x":["FAMILY","GAME","TOOLS","FINANCE","LIFESTYLE","PRODUCTIVITY","BUSINESS","PHOTOGRAPHY","SPORTS","COMMUNICATION","HEALTH_AND_FITNESS","PERSONALIZATION","MEDICAL","NEWS_AND_MAGAZINES","SOCIAL","TRAVEL_AND_LOCAL","SHOPPING","BOOKS_AND_REFERENCE","VIDEO_PLAYERS","DATING","EDUCATION","MAPS_AND_NAVIGATION","ENTERTAINMENT","FOOD_AND_DRINK","AUTO_AND_VEHICLES","WEATHER","LIBRARIES_AND_DEMO","HOUSE_AND_HOME","ART_AND_DESIGN","COMICS","PARENTING","EVENTS","BEAUTY"],"xaxis":"x","y":[1456,834,656,289,284,283,253,248,238,235,232,232,228,202,201,179,178,161,144,131,114,113,100,92,72,65,64,62,58,54,48,45,42],"yaxis":"y","type":"bar","cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eType=Paid\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["FAMILY","GAME","PERSONALIZATION","TOOLS","MEDICAL","COMMUNICATION","SPORTS","PRODUCTIVITY","LIFESTYLE","PHOTOGRAPHY","FINANCE","HEALTH_AND_FITNESS","BUSINESS","TRAVEL_AND_LOCAL","BOOKS_AND_REFERENCE","WEATHER","MAPS_AND_NAVIGATION","VIDEO_PLAYERS","EDUCATION","DATING","ART_AND_DESIGN","SOCIAL","SHOPPING","ENTERTAINMENT","FOOD_AND_DRINK","PARENTING","NEWS_AND_MAGAZINES","AUTO_AND_VEHICLES"],"legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.2s}","x":["FAMILY","GAME","PERSONALIZATION","TOOLS","MEDICAL","COMMUNICATION","SPORTS","PRODUCTIVITY","LIFESTYLE","PHOTOGRAPHY","FINANCE","HEALTH_AND_FITNESS","BUSINESS","TRAVEL_AND_LOCAL","BOOKS_AND_REFERENCE","WEATHER","MAPS_AND_NAVIGATION","VIDEO_PLAYERS","EDUCATION","DATING","ART_AND_DESIGN","SOCIAL","SHOPPING","ENTERTAINMENT","FOOD_AND_DRINK","PARENTING","NEWS_AND_MAGAZINES","AUTO_AND_VEHICLES"],"xaxis":"x","y":[154,76,64,63,63,22,22,18,18,15,13,11,9,8,8,7,5,4,4,3,3,2,2,2,2,2,2,1],"yaxis":"y","type":"bar","cliponaxis":false,"textangle":0}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{" ...

# %%
import plotly.graph_objects as go

# Assuming df_type is your DataFrame and it has columns "Category", "App", and "Type"
# Create separate dataframes for free and paid apps
df_free = df_type[df_type["Type"] == "Free"]
df_paid = df_type[df_type["Type"] == "Paid"]

# Create bar trace for free apps
bar_free = px.bar(df_free,
                  x="Category",
                  y="App",
                  color="Type",
                  color_discrete_map={"Free": "blue"},
                  hover_name="Category",
                  text_auto='.2s')

# Create bar trace for paid apps
bar_paid = px.bar(df_paid,
                  x="Category",
                  y="App",
                  color="Type",
                  color_discrete_map={"Paid": "orange"},
                  hover_name="Category",
                  text_auto='.2s')

# Combine the two traces
fig = bar_free.data[0]
fig.update(name="Free Apps")

fig_paid = bar_paid.data[0]
fig_paid.update(yaxis="y2", name="Paid Apps")

# Create the final figure
fig = go.Figure(data=[fig, fig_paid])

# Update layout to include two y-axes
fig.update_layout(
    title=dict(text="Free vs Paid Apps by Category", font=dict(size=40), yref='paper'),
    font=dict(family="Courier New, monospace", size=18),
    xaxis=dict(title='Category', tickangle=90),
    yaxis=dict(title='Number of Free Apps'),
    yaxis2=dict(title='Number of Paid Apps', overlaying='y', side='right', showgrid=False),
    barmode="group",
    coloraxis_showscale=False
)

fig.update_traces(textangle=0, textposition="outside", cliponaxis=False)
fig.show()

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
