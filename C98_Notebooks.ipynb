# %% [markdown]
# <a href="https://colab.research.google.com/github/KenkiCZ/google_notebooks/blob/main/C98_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer="salaries_by_college_major.csv")

# %%
df.head(5)
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (50, 6)

# %%
df["Undergraduate Major"].iloc[df["Starting Median Salary"].idxmax()]
# Out:
# 'Physician Assistant'

# %%
df["Mid-Career Median Salary"][df["Mid-Career Median Salary"].idxmax()]
# Out:
# 107000.0

# %%
df["Undergraduate Major"][df["Mid-Career Median Salary"].idxmax()]
# Out:
# 'Chemical Engineering'

# %%
f'{df["Undergraduate Major"][df["Starting Median Salary"].idxmin()]} major earns: {df["Starting Median Salary"][df["Starting Median Salary"].idxmin()]} $'
# Out:
# 'Spanish major earns: 34000.0 $'

# %%
f'{df["Undergraduate Major"][df["Mid-Career Median Salary"].idxmin()]} major earns: {df["Starting Median Salary"][df["Mid-Career Median Salary"].idxmin()]} $'
# Out:
# 'Education major earns: 34900.0 $'

# %%
df.insert(1, "Spread", df["Mid-Career 90th Percentile Salary"]-df["Mid-Career 10th Percentile Salary"]) # Calculating Difference between highest and lowest sallaries

# %%
df.sort_values("Spread")[["Undergraduate Major", "Spread"]].head(5)
# Out:
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %%
from matplotlib import pyplot as plt
_df_0['Spread'].plot(kind='hist', bins=20, title='Spread')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.sort_values("Mid-Career 90th Percentile Salary", ascending=False).head(5)
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 17             Economics  159400.0                 50100.0
# 22               Finance  147800.0                 47900.0
# 8   Chemical Engineering  122100.0                 63200.0
# 37                  Math  137800.0                 45400.0
# 44               Physics  122000.0                 50300.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 8                   107000.0                            71900.0
# 37                   92400.0                            45200.0
# 44                   97300.0                            56000.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# 22                           195000.0  Business
# 8                            194000.0      STEM
# ...

# %%
df.sort_values("Spread", ascending=False).head(5)
# Out:
#    Undergraduate Major    Spread  Starting Median Salary  \
# 17           Economics  159400.0                 50100.0
# 22             Finance  147800.0                 47900.0
# 37                Math  137800.0                 45400.0
# 36           Marketing  132900.0                 40800.0
# 42          Philosophy  132500.0                 39900.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 37                   92400.0                            45200.0
# 36                   79600.0                            42100.0
# 42                   81200.0                            35500.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# 22                           195000.0  Business
# 37                           183000.0      STEM
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format
df.drop('Undergraduate Major', axis=1).groupby('Group').mean()
# Out:
#              Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00
